# %% [markdown]
# #受難日第一天 20190923
#
# ##城市超簡單

# %%
 print("Hello MyDearGreatteacher")
# Out:
# Hello MyDearGreatteacher

# %%
print("    *    ")
print("   ***   ")
print("  *****  ")
print("    *    ")
print("    *    ")
print("    *    ")
# Out:
#     *
#    ***
#   *****
#     *
#     *
#     *
